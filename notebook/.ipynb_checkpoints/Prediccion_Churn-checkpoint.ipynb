# %% [markdown]
# # Práctica - Predicción de Churn en una compañia
#
#
# * En este notebook vamos a resolver un problema de predicción de Churn, en el que tenemos que clasificar (predecir) qué clientes que hacen uso de los servicios de una determinada empresa se darán de baja de sus servicios.
#
#
# * Para realizar este ejercicio de clasificación vamos a aplicar diferentes algoritmos, con los que creamos varios modelos y analizaremos cuál es de ellos es el que mejor nos predice el Churn.
#
#
# * El Dataset a utilizar esta en el fichero "Churn_Modelling.csv"

# %% [markdown]
# # Importamos las librerías

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

from keras.models import Sequential
from keras.layers import Dense, Dropout

from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.constraints import max_norm

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, auc, roc_auc_score

# %% [markdown]
# <hr>
#
#
# ## <a name="M1">Carga de datos</a>

# %%
df = pd.read_csv("/Users/jackyb/PycharmProjects/2_Churn_Model/data/input/Churn_Modelling.csv")
df.sample(5)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 5230       5231    15576641  Crawford          733   Germany    Male   40
# 584         585    15803689     Begum          647   Germany  Female   51
# 7572       7573    15567919   Lazarev          586   Germany    Male   37
# 2485       2486    15659501    Chioke          753    France  Female   38
# 4847       4848    15624596  Trentini          534    France  Female   23
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5230       5  125725.02              2          1               1
# 584        1  119741.77              2          0               0
# 7572       8  167735.69              2          0               1
# 2485       6  142263.45              1          0               1
# 4847       5  104822.45              1          0               1
#
#       EstimatedSalary  Exited
# 5230         50783.10       0
# 584          54954.51       1
# 7572        104665.79       0
# 2485         33730.43       0
# 4847        160176.47       0

# %% [markdown]
# <hr>
#
#
# ## <a name="M2">Preparación de los datos</a>
#
# ### <a name="M21">Análisis del desbalanceo de datos</a>
#
#
# * En el Dataset hay un 80% de clientes que no abandonan la compañia y un 20% que si.

# %%
churn = df['Exited'].value_counts()
print('Numero de Churns:\n{}'.format(churn))
# Out:
# Numero de Churns:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %% [markdown]
# ### <a name="M22">Particionado de datos en conjuntos de entrenamiento y test</a>
#
#
# * Vamos a dividir los datos en conjuntos de entrenamiento y test, seleccionando:
#     + 80% de entrenemiento
#     + 20% de test
#
#
# * Para ello seleccionamos los 8.000 primeros elementos de entrenamiento y los 2.000 último elementos de test.

# %%
df_train = df.iloc[:8000,:]
df_test = df.iloc[8000:,:]

print("elementos de entrenamiento {}".format(df_train.shape))
print("elementos de test {}".format(df_test.shape))
# Out:
# elementos de entrenamiento (8000, 14)
# elementos de test (2000, 14)

# %% [markdown]
# ### <a name="M23">Transformación de variables categóricas</a>
#
#
# * Dado que tenemos las variables "Gender" y "Geography" como categóricas y son variables interesantes para el análisis, tenemos que transformarlas a variables numéricas.
#
#
# * Para ello aplicaremos un:
#     + Codificación binaria para Gender
#     + One-hot para Geography

# %%
# Codificamos la variable Gender
lb = LabelBinarizer()
df_train['Gender'] = lb.fit_transform(df_train['Gender'])
df_test['Gender'] = lb.fit_transform(df_test['Gender'])

# Codificamos la variable geograpy
df_dummy_train = pd.get_dummies(df_train['Geography'])
df_dummy_test = pd.get_dummies(df_test['Geography'])
df_train = pd.concat([df_train, df_dummy_train], axis=1)
df_test = pd.concat([df_test, df_dummy_test], axis=1)
df_train = df_train.drop(['Geography'], 1)
df_test = df_test.drop(['Geography'], 1)

# mostramos un sample de entrenamiento
df_train.sample(5)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore  Gender  Age  Tenure  \
# 5423       5424    15749671          K?          794       1   35       6
# 525         526    15786063        Chin          776       0   31       2
# 3381       3382    15629511  Lavrentiev          738       1   49       6
# 313         314    15797960     Skinner          806       0   59       0
# 1429       1430    15626485          Lu          601       0   26       8
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 5423       0.00              2          1               1         68730.91
# 525        0.00              2          1               1        112349.51
# 3381  106770.82              1          1               0        123499.27
# 313   135296.33              1          1               0        182822.50
# 1429   78892.23              1          1               1         23703.52
#
#       Exited  France  Germany  Spain
# 5423       0       1        0      0
# 525        0       1        0      0
# 3381       0       1        0      0
# 313        0       0        1      0
# 1429       0       1        0      0

# %%
# mostramos un sample de test
df_test.sample(5)
# Out:
#       RowNumber  CustomerId Surname  CreditScore  Gender  Age  Tenure  \
# 8532       8533    15780805      Lu          585       0   35       2
# 8633       8634    15801414  Bitter          767       0   35       2
# 9552       9553    15772009   Scott          664       0   41       5
# 9684       9685    15635775    Watt          781       1   33       3
# 9425       9426    15683977   Owens          687       0   72       4
#
#        Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 8532      0.00              2          1               0         98621.04
# 8633      0.00              2          0               0        144251.38
# 9552      0.00              1          1               1        152054.33
# 9684  89276.48              1          1               0          6959.00
# 9425      0.00              2          1               1         50267.69
#
#       Exited  France  Germany  Spain
# 8532       1       1        0      0
# 8633       0       1        0      0
# 9552       0       1        0      0
# 9684       0       1        0      0
# 9425       0       0        0      1

# %% [markdown]
# ### <a name="M24">Adición de datos a la clase desbalanceada</a>
#
#
# * Dado que tenemos un porcentaje de clientes relativamente pequeño que abandonan la compañia, debemos de darles más peso para los algoritmos de aprendizaje.

# %%
NUM_SAMPLES=3000

df_train_class_des = df_train[df_train['Exited']==1].sample(NUM_SAMPLES, replace=True)
df_train_ext = pd.concat([df_train, df_train_class_des])
print("elementos de entrenamiento a añadir {}".format(len(df_train_class_des['Exited']==1)))
print("elementos del dataframe con los datos añadidos {}".format(len(df_train_ext[df_train_ext["Exited"]==0])))
# Out:
# elementos de entrenamiento a añadir 3000
# elementos del dataframe con los datos añadidos 6353

# %% [markdown]
# ### <a name="M25">Normalización Cambio de estructura de datos a numpy</a>

# %%
# Variables a seleccionar
X_features = ['CreditScore', 'Gender', 'Age', 'Tenure', 'Balance', 
               'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']
y_feature = ['Exited']

# Dataframes de entrenamiento y test
df_train_ext = df_train_ext[X_features + y_feature]
df_test = df_test[X_features + y_feature]

# Paso de datos a numpy y normalización
MMS = MinMaxScaler()
y_train = df_train_ext['Exited'].values
X_train = df_train_ext.drop(y_feature, 1).values
X_train_norm = MMS.fit_transform(X_train)

y_test = df_test['Exited'].values
X_test = df_test.drop(y_feature, 1).values
X_test_norm = MMS.fit_transform(X_test)

# %% [markdown]
# <hr>
#
# ## <a name="M3">Creacción y ajuste de los modelos</a>
#
# * Para la creación y ajuste de los modelos se proponen utilizar los siguientes Algoritmos de Aprendizaje:
#     - Clasificador dummy
#     - Gaussian Naive Bayes
#     - Decision Tree Classifier: Se propone crear un arbol de 5 niveles con criterio Gini
#     - Random Forest Classifier: Se propone crear un random forest con 100 estimadores y arboles de decisión de 5 niveles de profundidad
#     - Ada Boost: Se propone crear un Ada Boost con 100 Arboles de decisión de profundidad 5
#     - Neuronal Network

# %%
# Clasificador dummy
dm = DummyClassifier()

# Gaussian Naive Bayes
gnb = GaussianNB()

# Decision Tree con 5 niveles de profundidad
dtc_e = DecisionTreeClassifier(max_depth = 5, criterion = 'entropy', random_state = 1)
dtc_g = DecisionTreeClassifier(max_depth = 5, random_state = 1)

# Random forest con 100 estimadores y arboles de decisión de 5 niveles de profundidad
rfc_e = RandomForestClassifier(random_state=1, n_estimators=100, max_depth = 5, criterion = 'entropy')
rfc_e2 = RandomForestClassifier(random_state=1, n_estimators=300, max_depth = 5, criterion = 'entropy')
rfc_g = RandomForestClassifier(random_state=1, n_estimators=100, max_depth = 5)
rfc_g2 = RandomForestClassifier(random_state=1, n_estimators=300, max_depth = 5)

# Ada Boost con 100 Arboles de decisión de profundidad 5
abc_l1 = AdaBoostClassifier(n_estimators=100, random_state=0)
abc_l08 = AdaBoostClassifier(n_estimators=100, random_state=0, learning_rate=0.8)
abc_l1_est_mod = AdaBoostClassifier(n_estimators=300, random_state=0)
abc_l08_est_mod = AdaBoostClassifier(n_estimators=300, random_state=0, learning_rate=0.8)

# Red neuronal 
model = Sequential()

# input layer
model.add(Dense(120,  activation='relu'))
model.add(Dropout(0.2))

# hidden layer
model.add(Dense(80,  activation='relu'))
model.add(Dropout(0.2))

# hidden layer
model.add(Dense(40, activation='relu'))
model.add(Dropout(0.2))

# hidden layer
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.2))

# output layer
model.add(Dense(units=1,activation='sigmoid'))

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Red neuronal 2
model2 = Sequential()

# input layer
model2.add(Dense(120,  activation='relu'))
model2.add(Dropout(0.2))

# hidden layer
model2.add(Dense(80,  activation='relu'))
model2.add(Dropout(0.2))

# output layer
model2.add(Dense(units=1,activation='sigmoid'))

# Compile model
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Creamos un diccionario con los clasificadores
clasificadores = {'Dummy': dm,
                  'Gaussian': gnb,
                  'Decision Tree entropy': dtc_e,
                  'Decision Tree gini': dtc_g,
                  'Random Forest entropy': rfc_e,
                  'Random Forest gini': rfc_g,
                  'Random Forest entropy 2': rfc_e2,
                  'Random Forest gini 2': rfc_g2,
                  'Ada Boost 1':abc_l1,
                  'Ada Boost 08':abc_l08,
                  'Ada Boost 1 estimator mod':abc_l1_est_mod,
                  'Ada Boost 08 estimator mod':abc_l08_est_mod,
                  'Red Neuronal': model,
                  'Red Neuronal 2': model2}
# Out:
# 2022-09-06 20:03:23.312308: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# * Ajustamos los modelos

# %%
# Ajustamos los modelos
for k, v in clasificadores.items():
    print ('CREANDO MODELO: {clas}'.format(clas=k))
    if k == "Red Neuronal":
        model.fit(X_train_norm, 
              y_train, 
              validation_split=0.1, 
              epochs=20, 
              batch_size=32, 
              verbose=2)
    elif k == "Red Neuronal 2":
        model2.fit(X_train_norm, 
              y_train, 
              validation_split=0.1, 
              epochs=20, 
              batch_size=32, 
              verbose=2)
    else:
        v.fit(X_train_norm, y_train)
# Out:
# CREANDO MODELO: Dummy
# CREANDO MODELO: Gaussian
# CREANDO MODELO: Decision Tree entropy
# CREANDO MODELO: Decision Tree gini
# CREANDO MODELO: Random Forest entropy
# CREANDO MODELO: Random Forest gini
# CREANDO MODELO: Random Forest entropy 2
# CREANDO MODELO: Random Forest gini 2
# CREANDO MODELO: Ada Boost 1
# CREANDO MODELO: Ada Boost 08
# CREANDO MODELO: Ada Boost 1 estimator mod
# CREANDO MODELO: Ada Boost 08 estimator mod
# CREANDO MODELO: Red Neuronal
# Epoch 1/20
# 310/310 - 1s - loss: 0.6111 - accuracy: 0.6693 - val_loss: 0.9672 - val_accuracy: 0.3536 - 1s/epoch - 3ms/step
# Epoch 2/20
# 310/310 - 0s - loss: 0.5561 - accuracy: 0.7233 - val_loss: 0.9723 - val_accuracy: 0.3445 - 364ms/epoch - 1ms/step
# Epoch 3/20
# 310/310 - 0s - loss: 0.5127 - accuracy: 0.7541 - val_loss: 0.6423 - val_accuracy: 0.5318 - 388ms/epoch - 1ms/step
# Epoch 4/20
# 310/310 - 0s - loss: 0.4832 - accuracy: 0.7672 - val_loss: 0.5910 - val_accuracy: 0.5409 - 367ms/epoch - 1ms/step
# Epoch 5/20
# 310/310 - 0s - loss: 0.4737 - accuracy: 0.7725 - val_loss: 0.7738 - val_accuracy: 0.4864 - 361ms/epoch - 1ms/step
# Epoch 6/20
# 310/310 - 0s - loss: 0.4681 - accuracy: 0.7751 - val_loss: 0.9175 - val_accuracy: 0.3964 - 363ms/epoch - 1ms/step
# Epoch 7/20
# 310/310 - 0s - loss: 0.4652 - accuracy: 0.7739 - val_loss: 0.7683 - val_accuracy: 0.4555 - 356ms/epoch - 1ms/step
# Epoch 8/20
# 310/310 - 0s - loss: 0.4636 - accuracy: 0.7766 - val_loss: 0.7355 - val_accuracy: 0.4927 - 388ms/epoch - 1ms/step
# Epoch 9/20
# 310/310 - 0s - loss: 0.4593 - accuracy: 0.7787 - val_loss: 0.6569 - val_accuracy: 0.5064 - 347ms/epoch - 1ms/step
# Epoch 10/20
# 310/310 - 0s - loss: 0.4565 - accuracy: 0.7833 - val_loss: 0.6849 - val_accuracy: 0.5036 - 360ms/epoch - 1ms/step
# Epoch 11/20
# 310/310 - 0s - loss: 0.4512 - accuracy: 0.7816 - val_loss: 0.6323 - val_accuracy: 0.5618 - 378ms/epoch - 1ms/step
# Epoch 12/20
# 310/310 - 0s - loss: 0.4514 - accuracy: 0.7849 - val_loss: 0.6134 - val_accuracy: 0.6355 - 362ms/epoch - 1ms/step
# Epoch 13/20
# 310/310 - 0s - loss: 0.4541 - accuracy: 0.7819 - val_loss: 0.6300 - val_accuracy: 0.5927 - 362ms/epoch - 1ms/step
# Epoch 14/20
# 310/310 - 0s - loss: 0.4460 - accuracy: 0.7911 - val_loss: 0.6422 - val_accuracy: 0.5664 - 351ms/epoch - 1ms/step
# Epoch 15/20
# 310/310 - 0s - loss: 0.4423 - accuracy: 0.7879 - val_loss: 0.6363 - val_accuracy: 0.6136 - 361ms/epoch - 1ms/step
# Epoch 16/20
# 310/310 - 0s - loss: 0.4406 - accuracy: 0.7894 - val_loss: 0.5961 - val_accuracy: 0.6627 - 377ms/epoch - 1ms/step
# Epoch 17/20
# 310/310 - 0s - loss: 0.4380 - accuracy: 0.7934 - val_loss: 0.7008 - val_accuracy: 0.6127 - 346ms/epoch - 1ms/step
# Epoch 18/20
# 310/310 - 0s - loss: 0.4376 - accuracy: 0.7889 - val_loss: 0.5952 - val_accuracy: 0.6218 - 357ms/epoch - 1ms/step
# Epoch 19/20
# 310/310 - 0s - loss: 0.4366 - accuracy: 0.7957 - val_loss: 0.6814 - val_accuracy: 0.5818 - 361ms/epoch - 1ms/step
# Epoch 20/20
# 310/310 - 0s - loss: 0.4332 - accuracy: 0.7960 - val_loss: 0.7219 - val_accuracy: 0.5336 - 363ms/epoch - 1ms/step
# CREANDO MODELO: Red Neuronal 2
# Epoch 1/20
# 310/310 - 1s - loss: 0.5963 - accuracy: 0.6807 - val_loss: 0.7336 - val_accuracy: 0.5245 - 721ms/epoch - 2ms/step
# Epoch 2/20
# 310/310 - 0s - loss: 0.5394 - accuracy: 0.7299 - val_loss: 0.9040 - val_accuracy: 0.4700 - 309ms/epoch - 998us/step
# Epoch 3/20
# 310/310 - 0s - loss: 0.4956 - accuracy: 0.7566 - val_loss: 0.6742 - val_accuracy: 0.5736 - 299ms/epoch - 965us/step
# Epoch 4/20
# 310/310 - 0s - loss: 0.4763 - accuracy: 0.7662 - val_loss: 0.6579 - val_accuracy: 0.5900 - 305ms/epoch - 985us/step
# Epoch 5/20
# 310/310 - 0s - loss: 0.4684 - accuracy: 0.7731 - val_loss: 0.6667 - val_accuracy: 0.5664 - 288ms/epoch - 929us/step
# Epoch 6/20
# 310/310 - 0s - loss: 0.4641 - accuracy: 0.7723 - val_loss: 0.7887 - val_accuracy: 0.5009 - 305ms/epoch - 985us/step
# Epoch 7/20
# 310/310 - 0s - loss: 0.4582 - accuracy: 0.7796 - val_loss: 0.6183 - val_accuracy: 0.6000 - 304ms/epoch - 982us/step
# Epoch 8/20
# 310/310 - 0s - loss: 0.4602 - accuracy: 0.7742 - val_loss: 0.6680 - val_accuracy: 0.5418 - 289ms/epoch - 933us/step
# Epoch 9/20
# 310/310 - 0s - loss: 0.4558 - accuracy: 0.7783 - val_loss: 0.6533 - val_accuracy: 0.5645 - 308ms/epoch - 994us/step
# Epoch 10/20
# 310/310 - 0s - loss: 0.4503 - accuracy: 0.7798 - val_loss: 0.7837 - val_accuracy: 0.4927 - 298ms/epoch - 960us/step
# Epoch 11/20
# 310/310 - 0s - loss: 0.4503 - accuracy: 0.7782 - val_loss: 0.6402 - val_accuracy: 0.5700 - 291ms/epoch - 939us/step
# Epoch 12/20
# 310/310 - 0s - loss: 0.4483 - accuracy: 0.7821 - val_loss: 0.7095 - val_accuracy: 0.5318 - 323ms/epoch - 1ms/step
# Epoch 13/20
# 310/310 - 0s - loss: 0.4458 - accuracy: 0.7843 - val_loss: 0.6960 - val_accuracy: 0.5209 - 292ms/epoch - 942us/step
# Epoch 14/20
# 310/310 - 0s - loss: 0.4455 - accuracy: 0.7870 - val_loss: 0.6296 - val_accuracy: 0.5873 - 307ms/epoch - 991us/step
# Epoch 15/20
# 310/310 - 0s - loss: 0.4409 - accuracy: 0.7856 - val_loss: 0.7012 - val_accuracy: 0.5473 - 296ms/epoch - 955us/step
# Epoch 16/20
# 310/310 - 0s - loss: 0.4425 - accuracy: 0.7848 - val_loss: 0.6742 - val_accuracy: 0.5627 - 292ms/epoch - 942us/step
# Epoch 17/20
# 310/310 - 0s - loss: 0.4427 - accuracy: 0.7871 - val_loss: 0.6788 - val_accuracy: 0.5700 - 302ms/epoch - 974us/step
# Epoch 18/20
# 310/310 - 0s - loss: 0.4386 - accuracy: 0.7904 - val_loss: 0.5599 - val_accuracy: 0.6518 - 288ms/epoch - 928us/step
# Epoch 19/20
# 310/310 - 0s - loss: 0.4397 - accuracy: 0.7900 - val_loss: 0.6814 - val_accuracy: 0.5764 - 312ms/epoch - 1ms/step
# Epoch 20/20
# 310/310 - 0s - loss: 0.4374 - accuracy: 0.7927 - val_loss: 0.6764 - val_accuracy: 0.5791 - 287ms/epoch - 925us/step

# %% [markdown]
# <hr>
#
# ## <a name="M4">Evaluación de los modelos</a>
#
# * Se propone evaluar los modelos tanto con el conjunto de datos de entrenamiento como de test con la métricas de:
#
#     + Accuracy
#     + Precision
#     + Recall
#     + F1

# %%
evaluacion = list()
for k, v in clasificadores.items():
    print ('EVALUANDO MODELO: {model}'.format(model=k))
    model = {}
    model['name'] = k
    if k == "Red Neuronal" or k =='Red Neuronal 2':
        y_pred_train = (v.predict(X_train_norm) > 0.5).astype("int32")
        y_pred_test = (v.predict(X_test_norm) > 0.5).astype("int32")
    else:
        y_pred_train = v.predict(X_train_norm)
        y_pred_test = v.predict(X_test_norm)
        
    model['accuracy_train'] = accuracy_score(y_true=y_train, y_pred=y_pred_train)
    model['accuracy_tests'] = accuracy_score(y_true=y_test, y_pred=y_pred_test)
    model['precision_train'] = precision_score(y_true=y_train, y_pred=y_pred_train)
    model['precision_tests'] = precision_score(y_true=y_test, y_pred=y_pred_test)
    model['recall_train'] = recall_score(y_true=y_train, y_pred=y_pred_train)
    model['recall_tests'] = recall_score(y_true=y_test, y_pred=y_pred_test)
    model['f1_train'] = f1_score(y_true=y_train, y_pred=y_pred_train)
    model['f1_tests'] = f1_score(y_true=y_test, y_pred=y_pred_test)
    model['AUC_train'] = roc_auc_score(y_train, y_pred_train)
    model['AUC_test'] = roc_auc_score(y_test, y_pred_test)
    evaluacion.append(model)

# Pasamos los resultados a un DataFrame para visualizarlos mejor
df = pd.DataFrame.from_dict(evaluacion)
df.set_index("name", inplace=True)
df.sort_values('f1_tests', ascending=False)
# Out:
# EVALUANDO MODELO: Dummy
# EVALUANDO MODELO: Gaussian
# EVALUANDO MODELO: Decision Tree entropy
# EVALUANDO MODELO: Decision Tree gini
# EVALUANDO MODELO: Random Forest entropy
# EVALUANDO MODELO: Random Forest gini
# EVALUANDO MODELO: Random Forest entropy 2
# EVALUANDO MODELO: Random Forest gini 2
# EVALUANDO MODELO: Ada Boost 1
# EVALUANDO MODELO: Ada Boost 08
# EVALUANDO MODELO: Ada Boost 1 estimator mod
# EVALUANDO MODELO: Ada Boost 08 estimator mod
# EVALUANDO MODELO: Red Neuronal
# 344/344 [==============================] - 0s 596us/step
# 63/63 [==============================] - 0s 594us/step
# EVALUANDO MODELO: Red Neuronal 2
# 344/344 [==============================] - 0s 627us/step
# 63/63 [==============================] - 0s 601us/step
#                             accuracy_train  accuracy_tests  precision_train  \
# name
# Random Forest gini 2              0.779364          0.7960         0.810403
# Random Forest entropy             0.775909          0.7875         0.798904
# Random Forest entropy 2           0.778818          0.7920         0.805464
# Decision Tree gini                0.775364          0.7950         0.787223
# Random Forest gini                0.779636          0.7925         0.812307
# Red Neuronal 2                    0.774182          0.8085         0.835974
# Decision Tree entropy             0.771455          0.7760         0.768843
# Red Neuronal                      0.775727          0.8270         0.881119
# Ada Boost 08                      0.779000          0.7650         0.763684
# Ada Boost 08 estimator mod        0.784091          0.7650         0.770992
# Ada Boost 1                       0.781364          0.7605         0.768825
# Ada Boost 1 estimator mod         0.787000          0.7610         0.774025
# Gaussian                          0.737091          0.7425         0.733440
# Dummy                             0.577545          0.8050         0.000000
#
#                             precision_tests  recall_train  recall_tests  \
# name
# Random Forest gini 2               0.483395      0.623628      0.671795
# Random Forest entropy              0.469671      0.627502      0.694872
# Random Forest entropy 2            0.476619      0.628147      0.679487
# Decision Tree gini                 0.481550      0.641704      0.669231
# Random Forest gini                 0.477314      0.622122      0.674359
# Red Neuronal 2                     0.507865      0.579083      0.579487
# Decision Tree entropy              0.450512      0.656337      0.676923
# Red Neuronal                       0.561453      0.542285      0.515385
# Ada Boost 08                       0.433993      0.690553      0.674359
# Ada Boost 08 estimator mod         0.433775      0.695502      0.671795
# Ada Boost 1                        0.426929      0.689907      0.666667
# Ada Boost 1 estimator mod          0.427393      0.700237      0.664103
# Gaussian                           0.399679      0.593286      0.638462
# Dummy                              0.000000      0.000000      0.000000
#
#                             f1_train  f1_tests  AUC_train  AUC_test
# name
# Random Forest gini 2        0.704852  0.562232   0.758453  0.748941
# Random Forest entropy       0.702905  0.560496   0.755983  0.752405
# Random Forest entropy 2     0.705840  0.560254   0.758588  0.749371
# Decision Tree gini          0.707054  0.560086   0.757418  0.747348
# Random Forest gini          0.704606  0.558980   0.758487  0.747738
# Red Neuronal 2              0.684211  0.541317   0.747986  0.721731
# Decision Tree entropy       0.708150  0.540984   0.755998  0.738462
# Red Neuronal                0.671373  0.537433   0.744384  0.708935
# Ada Boost 08                0.725280  0.528112   0.767124  0.730658
# Ada Boost 08 estimator mod  0.731304  0.527163   0.772196  0.729686
# Ada Boost 1                 0.727231  0.520521   0.769084  0.724948
# Ada Boost 1 estimator mod   0.735284  0.520080   0.775351  0.724287
# Gaussian                    0.655960  0.491609   0.717783  0.703082
# Dummy                       0.000000  0.000000   0.500000  0.500000

# %% [markdown]
# ### <a name="M41">Matrices de confusión</a>
#
# * A continuación se pintarán las matrices de confusión para los diferentes modelos generados tanto para los datos de entrenamiento como los datos de test.

# %%
def plot_confusion_matrix(cm, classes, title, cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    
# Calculamos las matrices de confusión
msc = list()
for k, v in clasificadores.items():
    print ('Obteniendo Matriz de Confusión de: {model}'.format(model=k))
    model = {}
    model['name'] = k
    if k == "Red Neuronal" or k == 'Red Neuronal 2':
        y_pred_train = (v.predict(X_train_norm) > 0.5).astype("int32")
        y_pred_test = (v.predict(X_test_norm) > 0.5).astype("int32")
    else:
        y_pred_train = v.predict(X_train_norm)
        y_pred_test = v.predict(X_test_norm)
    model['confusion_matrix_train'] = confusion_matrix(y_true=y_train, y_pred=y_pred_train)
    model['confusion_matrix_test'] = confusion_matrix(y_true=y_test, y_pred=y_pred_test)
    msc.append(model)
# Out:
# Obteniendo Matriz de Confusión de: Dummy
# Obteniendo Matriz de Confusión de: Gaussian
# Obteniendo Matriz de Confusión de: Decision Tree entropy
# Obteniendo Matriz de Confusión de: Decision Tree gini
# Obteniendo Matriz de Confusión de: Random Forest entropy
# Obteniendo Matriz de Confusión de: Random Forest gini
# Obteniendo Matriz de Confusión de: Random Forest entropy 2
# Obteniendo Matriz de Confusión de: Random Forest gini 2
# Obteniendo Matriz de Confusión de: Ada Boost 1
# Obteniendo Matriz de Confusión de: Ada Boost 08
# Obteniendo Matriz de Confusión de: Ada Boost 1 estimator mod
# Obteniendo Matriz de Confusión de: Ada Boost 08 estimator mod
# Obteniendo Matriz de Confusión de: Red Neuronal
# 344/344 [==============================] - 0s 546us/step
# 63/63 [==============================] - 0s 601us/step
# Obteniendo Matriz de Confusión de: Red Neuronal 2
# 344/344 [==============================] - 0s 579us/step
# 63/63 [==============================] - 0s 587us/step

# %% [markdown]
# * Pintamos las matrices de confusión con el conjunto de datos de entrenamiento.

# %%
fig = plt.figure(figsize=(20, 60))
for i, mc in enumerate(msc):
    ax = plt.subplot(10, 2, i+1)
    sns.set(font_scale=1.5) 
    sns.heatmap(mc['confusion_matrix_train'],annot=True, ax=ax, cmap="YlGnBu", fmt="g")
    #plot_confusion_matrix(mc['confusion_matrix_train'], classes=['0', '1'], 
                          #title='{}\nMatriz de Confusión Datos Entrenamiento'.format(mc['name']))
    label_font = {'size':'13'}
    ax.set_xlabel('Predicted labels', fontdict=label_font);
    ax.set_ylabel('Observed labels', fontdict=label_font);
    title_font = {'size':'10'}
    ax.set_title('{}\nMatriz de Confusión Datos Entrenamiento'.format(mc['name']));
    
fig.tight_layout()
plt.show()

# %% [markdown]
# * Pintamos las matrices de confusión con el conjunto de datos de test.

# %%
fig = plt.figure(figsize=(20, 60))
for i, mc in enumerate(msc):
    ax = plt.subplot(10, 2, i+1)
    sns.set(font_scale=1.5) 
    sns.heatmap(mc['confusion_matrix_test'],annot=True, ax=ax, cmap="YlGnBu", fmt="g")
    #plot_confusion_matrix(mc['confusion_matrix_train'], classes=['0', '1'], 
                          #title='{}\nMatriz de Confusión Datos Entrenamiento'.format(mc['name']))
    label_font = {'size':'13'}
    ax.set_xlabel('Predicted labels', fontdict=label_font);
    ax.set_ylabel('Observed labels', fontdict=label_font);
    title_font = {'size':'10'}
    ax.set_title('{}\nMatriz de Confusión Datos Test'.format(mc['name']));
    
fig.tight_layout()
plt.show()

# %% [markdown]
# <hr>
#
# ## <a name="M5">Conclusiones</a>
